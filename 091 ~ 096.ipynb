# %% [markdown]
# # 91. 분석 거버넌스 체계 구성 요소
# * 데이터를 수집, 축적하는 것보다는 어떤 목적으로 어떤 데이터를 어떻게 분석에 활용할 것인가 더욱 중요하기 때문에 분석 관리체계를 수립 해야 한다.</br></br>
# *  ① 조직
# * ② 과제기획 및 운영프로세스
# * ③ 분석 관련 시스템(IT시스템&프로그램)
# * ④ 데이터(데이터 거버넌스)
# * ⑤ 분석 관련 교육 및 마인드 육성체계
#
# #### 출제유형
# * 분석 거버넌스 5개 구성요소가 출제

# %% [markdown]
# # 92. 데이터 분석 성숙도 모델 및 수준 진단
# * 기업들은 데이터 분석의 도입 여부와 활용에 대해 명확하게 분석 수준을 점검할 필요가 있다.
# * 데이터 분석 수준 진단은 6개의 영역의 분석 준비도와 3개 영역에서의 분석 성숙도를 함께 평가함으로써 수행한다.
#
# ![image.png](attachment:bc8bbd6e-44c7-46f4-8f6d-1167aa5cd1da.png)
#
# |① 분석 업무 파악|② 인력 및 조직|③ 분석기법|
# |-|-|-|
# |발생한 사실 여부 파악|분석전문가 직무 존재|업무별 적합한 분석기법 사용|
# |예측 분석업무|분석전문가 교육 훈련 프로그램|분석업무 도입 방법론|
# |시뮬레이션 분석업무|관리자들의 기본적 분석 능력|분석기법 라이브러리|
# |최적화 분석 업무|전사 분석업무 총괄 조직 존재|분석기법 효과성 평가|
# |분석 업무 정기적 개선|경영진 분석업무 이해 능력|분석기법 정기적 개선|
#
#
# </br></br>
# |④ 분석 데이터|⑤ 분석문화|⑥ IT 인프라|
# |-|-|-|
# |분석업무를 위한 데이터 충분성|사실에 근거한 의사결정|운영시스템 데이터 통합|
# |분석업무를 위한 데이터 신뢰성|관리자의 데이터 중시|EAI, ETL 등 데이터 유통체계|
# |분석업무를 위한 데이터 적시성|회의 등에서 데이터 활용|분석 전용 서버 및 스토리지|
# |비구조적 데이터 관리|경영진의 직관보다 데이터|빅데이터 분석 환경|
# |외부 데이터 활용 체계|데이터 공유 및 협업문화|통계 분석 환경|
# | 기준데이터 관리||비주얼 분석 환경|
# # 출제유형
# * 분석준비도 6개 영역과 세부 내용 구분이 출제

# %% [markdown]
# # 93. 분석 성숙도 모델
# * 시스템 개발 업무능력과 조직의 성숙도를 파악하기 위해 CMMI 모델을 기반으로 조직의 성숙도를 평가한다.
# * 분석 성숙도 진단은 비즈니스 부문, 조직·역량 부문, IT 부문 대상으로 도입단계, 활용단계, 확산단계, 최적화 단계 구분한다.
#
# ![image.png](attachment:37a47c22-c9fc-470c-8b55-a4ce062ebe1c.png)
#
# #### 용어정리
# * CMMI는 Capability Maturity Model Integration이다.
# * 직역하면 능력 성숙모델통합이다.
# * 프로젝트를 하는 능력이 얼마나 성숙되었는지를 알 수 있도록 만든 모델이다
#
# #### 출제유형
# * 3개 영역별 도입, 활용, 확산, 최적화 단계 구분 출제

# %% [markdown]
# # 94. 분석 수준 진단 결과 유형별 특성 구분
#
# ![image.png](attachment:77f8edfa-48e0-46c6-a1b3-ec06e7fdd5b5.png)
#
# * 정착형
#     * 준비도는 낮으나 조직, 인력, 분석 업무, 분석 기법 등을 기업 내부에서 제한적으로 사용하고 있어 1차적으로 정착이 필요한 기업</br></br>
# * 확산형
#     * 기업에 필요한 6가지 분석 구성 요소를 갖추고 있고, 현재 부분적으로 도입되어 지속적인 확산이 필요한 기업</br></br>
# * 준비형
#     * 기업에 필요한 데이터, 인력, 조직, 분석 업무, 분석기법 등이 적용되어 있지 않아 사전준비가 필요한 기업</br></br>
# * 도입형
#     *  기업에서 활용하는 분석업무, 기법 등은 부족하지만 적용 조직 등 준비도가 높아 바로 도입할 수 있는 기업</br></br>
# #### 출제유형
# * 분석준비도와 분석 성숙도에 따른 유형별 특성이 출제

# %% [markdown]
# # 95.데이터 거버넌스란
# *  전사 차원의 모든 데이터에 대하여 정책 및 지침, 표준화, 운영조직 및 책임 등의 표준화된 관리체계를 수립하고 운영을 위한 프레임워크, 저장소를 구축하는 것을 말한다.
# *  마스터 데이터, 메타 데이터, 데이터 사전은 데이터 거버넌스의 중요한 관리 대상이다.
# *  → 데이터 거버넌스를 구축함으로써 데이터의 가용성, 유용성, 통합성, 보안성, 안정성을 확보
# #### 출제유형
# * 데이터 거버넌스 정의가 출제

# %% [markdown]
# # 96. 빅데이터 거버넌스와 데이터 거버넌스 차이점
# * 빅데이터 거버넌스는 이러한 데이터 거버넌스의 체계에 더하여 빅데이터의 효율적인 관리, 다양한 데이터의 관리체계, 데이터 최적화, 정보보호, 데이터 생명주기 관리, 데이터 카테고리별 관리 책임자 (Data Steward)지정 등을 포함한다.
# #### 출제유형
# * 데이터 거버넌스와 빅데이터 거버넌스 차이 출제
